# %% [markdown]
# ![image.png](attachment:image.png)

# %%
abs(-45)
# Out:
# 45

# %%
abs(45)
# Out:
# 45

# %% [markdown]
# ## square root of a number

# %%
n = float(input("Hey, Enter your number to be square rooted: "))

x_0 = float(input(f"Hey, Enter the initial guess of the square root of {n}: "))


x = x_0

count = 0

print(f"The value of x_{count} is {x}")

while (abs(x**2-n)>0.00000000001):
    print("====================")
    f_x = x**2 - n 
    f_dx = 2*x
    x = x - f_x/f_dx
    count+=1
    
    print(f"The value of x_{count} is {x}")

print(f"\n \n Result: The square root of {n} is {x}")
print(f"\n \n The Actual Square Root of {n} is {n**0.5}")
print(f'\n The num of iterations used = {count}')
# Out:
# Hey, Enter your number to be square rooted: 78437824723
# Hey, Enter the initial guess of the square root of 78437824723.0: 2
# The value of x_0 is 2.0
# ====================
# The value of x_1 is 19609456181.75
# ====================
# The value of x_2 is 9804728092.875
# ====================
# The value of x_3 is 4902364050.4375
# ====================
# The value of x_4 is 2451182033.21875
# ====================
# The value of x_5 is 1225591032.609375
# ====================
# The value of x_6 is 612795548.304687
# ====================
# The value of x_7 is 306397838.15233904
# ====================
# The value of x_8 is 153199047.07613388
# ====================
# The value of x_9 is 76599779.53778176
# ====================
# The value of x_10 is 38300401.766609386
# ====================
# The value of x_11 is 19151224.86505299
# ====================
# The value of x_12 is 9577660.286522146
# ====================
# The value of x_13 is 4792924.975525764
# ====================
# The value of x_14 is 2404645.1554578207
# ====================
# The value of x_15 is 1218632.2241948287
# ====================
# The value of x_16 is 641498.8425248922
# ====================
# The value of x_17 is 381885.7940221182
# ====================
# The value of x_18 is 293640.91033183876
# ====================
# The value of x_19 is 280381.2465324199
# ====================
# The value of x_20 is 280067.71150422515
# ====================
# The value of x_21 is 280067.5360034268
# ====================
# The value of x_22 is 280067.5360033719
#
#
#  Result: The square root of 78437824723.0 is 280067.5360033719
#
#
#  The Actual Square Root of 78437824723.0 is 280067.5360033719
#
#  The num of iterations used = 22

# %% [markdown]
# ## Klinkenberg
#
# $ k(g) = k(L) + c(1/pm)$
#
# kg = measured gas permeability pm = mean pressure kL = equivalent liquid permeability, i.e., absolute permeability, k c = slope of the line
#
# $ c = b.k(L) = 6.9 (kL)^{-0.36}$
#
# $ 6.9(k_L)^{0.64} + p_m * k_L - p_m * k_g = 0 = f(k_L) $
#
# $ f'(k_L) = 4.416*k_L^{-0.36} + p_m$

# %% [markdown]
# **Example : - The permeability of a core plug is measured by air. Only one measurement is made at a mean pressure of 2.152 psi. The air permeability is 46.6 md. Estimate the absolute permeability of the core sample. Compare the result with the actual absolute permeability of 23.66 md.**

# %%
pm = 2.152

kg = 46.6

k = float(input("Enter your initial guess of absolute permeability kl: "))


count = 0
print(f"The value of kl_{count} is {k}")

while (abs(6.9*(k**0.64)+pm*k-pm*kg)>0.000000000001):
    print("=======================")
    updated_value = (6.9*(k**0.64)+pm*k-pm*kg)/(4.416*(k**(-0.36)) + pm) #f(k_l)/f'(k_l)
    k = k - updated_value
    count = count+1
    print(f"The value of kl_{count} is {k}")
    

print(f"The final value of Perm K is : {k}")
print(f"The Actual value of Perm K is : {23.66}")

print(f"The % Error is : {100*abs((k-23.66)/k)}")
# Out:
# Enter your initial guess of absolute permeability kl: 200
# The value of kl_0 is 200.0
# =======================
# The value of kl_1 is 9.447443749398275
# =======================
# The value of kl_2 is 21.80541159614308
# =======================
# The value of kl_3 is 22.84545094640182
# =======================
# The value of kl_4 is 22.849002239774762
# =======================
# The value of kl_5 is 22.849002279471133
# The final value of Perm K is : 22.849002279471133
# The Actual value of Perm K is : 23.66
# The % Error is : 3.549379139663855

# %%
pm = float(input("Enter the mean pressure at which permeability is measured in lab (p_m): "))

kg = float(input("Enter the gas permeability measures in lab(k_g): "))

k = float(input("Enter your initial guess of absolute permeability kl: "))


count = 0
print(f"The value of kl_{count} is {k}")

while (abs(6.9*(k**0.64)+pm*k-pm*kg)>0.000000000001):
    print("=======================")
    updated_value = (6.9*(k**0.64)+pm*k-pm*kg)/(4.416*(k**(-0.36)) + pm) #f(k_l)/f'(k_l)
    k = k - updated_value
    count = count+1
    print(f"The value of kl_{count} is {k}")
    

print(f"The final value of Perm K is : {k}")
# Out:
# Enter the mean pressure at which permeability is measured in lab (p_m): 20
# Enter the gas permeability measures in lab(k_g): 32
# Enter your initial guess of absolute permeability kl: 23
# The value of kl_0 is 23.0
# =======================
# The value of kl_1 is 29.00477770642345
# =======================
# The value of kl_2 is 29.021743155710915
# =======================
# The value of kl_3 is 29.021743265789457
# The final value of Perm K is : 29.021743265789457

# %% [markdown]
# ## Python function: does some specific task for our input and return something back to us

# %%
print("Hello Debasmitha, welcome to the clas")
# Out:
# Hello Debasmitha, welcome to the clas

# %%
print("Hello Kishore, welcome to the clas")
# Out:
# Hello Kishore, welcome to the clas

# %%
print("Hello Chaitanya, welcome to the clas")
# Out:
# Hello Chaitanya, welcome to the clas

# %%
def greet(name_of_attendee):
    print(f"Hello {name_of_attendee}, welcome to the class")

# %%
greet("Debasmitha")
# Out:
# Hello Debasmitha, welcome to the class

# %%
greet("KISHOR")
# Out:
# Hello KISHOR, welcome to the class

# %%
def greet():
    name_of_attendee = input("Write the name of the attendee")
    print(f"Hello {name_of_attendee}, welcome to the class")

# %%
greet()
# Out:
# Write the name of the attendeeChaitanya
# Hello Chaitanya, welcome to the class

# %%
def debasmitha(name_of_attendee):
    print(f"Hello {name_of_attendee}, welcome to the class")

# %%
debasmitha("KISHOR")
# Out:
# Hello KISHOR, welcome to the class

# %%
def add(x,y):
    z = x+y
    print(f"Sum of {x} and {y} is {z}")

# %%
add(4,5)
# Out:
# Sum of 4 and 5 is 9

# %%
c = add(4,5)
# Out:
# Sum of 4 and 5 is 9

# %%
c

# %%
def add(x,y):
    z = x+y
    print(f"Sum of {x} and {y} is {z}")
    
    return z
print("hello")
# Out:
# hello

# %%
c = add(4,5)
# Out:
# Sum of 4 and 5 is 9

# %%
c
# Out:
# 9

# %%
def math_op(x,y):
    add = x+y
    sub = x-y
    mul = x*y
    div = x/y
    
    return add,sub,mul,div

# %%
r = math_op(6,2)

# %%
r
# Out:
# (8, 4, 12, 3.0)

# %%
a,b,c,d = math_op(6,2)

# %%
a
# Out:
# 8

# %%
b
# Out:
# 4

# %%
c
# Out:
# 12

# %%
d
# Out:
# 3.0

# %%
def klinkenberg(kg,km,k):
    
    """
    This klinkenberg function calculates absolute permeability for given gas permeability at a given mean pressure.
    
    INPUTS:
    kg=> gas permeability in lab at a given mean pressure pm
    pm => mean pressure
    k=>User initial guess for absolute perm.
    
    return:
    k=> value of absolute permeability 
    
    """




    count = 0
    print(f"The value of kl_{count} is {k}")

    while (abs(6.9*(k**0.64)+pm*k-pm*kg)>0.000000000001):
        print("=======================")
        updated_value = (6.9*(k**0.64)+pm*k-pm*kg)/(4.416*(k**(-0.36)) + pm) #f(k_l)/f'(k_l)
        k = k - updated_value
        count = count+1
        print(f"The value of kl_{count} is {k}")


    print(f"The final value of Perm K is : {k}")
    
    return k

# %%
abs_perm = klinkenberg(56,32,2)
# Out:
# The value of kl_0 is 2
# =======================
# The value of kl_1 is 47.614823265285175
# =======================
# The value of kl_2 is 51.68758406916255
# =======================
# The value of kl_3 is 51.69073475461635
# =======================
# The value of kl_4 is 51.690734756367384
# The final value of Perm K is : 51.690734756367384

# %%
abs_perm
# Out:
# 51.690734756367384

# %%
klinkenberg(56,32,2)
# Out:
# The value of kl_0 is 2
# =======================
# The value of kl_1 is 47.614823265285175
# =======================
# The value of kl_2 is 51.68758406916255
# =======================
# The value of kl_3 is 51.69073475461635
# =======================
# The value of kl_4 is 51.690734756367384
# The final value of Perm K is : 51.690734756367384
# 51.690734756367384
